# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import sys
sys.path.insert(0, '..')
import paths
from os.path import join
import time
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %%
start = time.time()
xyzrgb = np.loadtxt(join(paths.DATA_DIR, 'office_1.txt'))
end = time.time()
print('Loading {} xyzrgb points takes {:.02f} seconds.'.format(xyzrgb.shape[0], end-start))
# Out:
# Loading 884955 xyzrgb points takes 4.90 seconds.

# %%
xyzrgb.shape
# Out:
# (884955, 6)

# %%
for i in range(xyzrgb.shape[1]):
    print('Min for column {} is {}'.format('xyzrgb'[i], xyzrgb[:,i].min()))
    print('Max for column {} is {}'.format('xyzrgb'[i], xyzrgb[:,i].max()))
# Out:
# Min for column x is -21.127
# Max for column x is -15.231
# Min for column y is 33.713
# Max for column y is 36.707
# Min for column z is 0.045
# Max for column z is 3.371
# Min for column r is 0.0
# Max for column r is 255.0
# Min for column g is 0.0
# Max for column g is 255.0
# Min for column b is 0.0
# Max for column b is 255.0

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
start = time.time()

skip_factor = 100
ax.scatter(xyzrgb[::skip_factor, 0], xyzrgb[::skip_factor, 1], xyzrgb[::skip_factor, 2], s = 1)
plt.show()
print('Plotting {} points takes {} seconds.'.format(int(xyzrgb.shape[0]/skip_factor), time.time()-start))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Plotting 8849 points takes 0.241217136383 seconds.
